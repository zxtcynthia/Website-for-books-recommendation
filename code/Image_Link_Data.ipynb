# %% [markdown]
# # Image Link Data

# %%
import sqlite3
import json
from pprint import pprint
import pandas as pd
import numpy as np
import re

# %%
df1 = pd.read_csv('/Users/siliwang/Desktop/Books_ISBN_Image.csv', encoding = "ISO-8859-1")

# %%
ISBN_list_big = df1.ISBN.tolist()

# %%
ISBN_list_small = df_imagelink.ISBN.tolist()

# %%
len(ISBN_list_big)
# Out:
# 17406

# %%
len(ISBN_list_small)
# Out:
# 115253

# %%
common_ISBN = list(set(ISBN_list_small).intersection(ISBN_list_big))
len(common_ISBN)
# Out:
# 7205

# %%
df1['Image_L'] = 0
df1['Image_M'] = 0
df1['Image_S'] = 0

# %%
for ISBN in common_ISBN:
    row_index = df1[df1['ISBN'] == ISBN].index[0]
    #print(row_index)
    df1['Image_L'][row_index] = df_imagelink.loc[df_imagelink['ISBN'] == ISBN, 'Image.URL.L'].iloc[0]
    df1['Image_M'][row_index] = df_imagelink.loc[df_imagelink['ISBN'] == ISBN, 'Image.URL.M'].iloc[0]
    df1['Image_S'][row_index] = df_imagelink.loc[df_imagelink['ISBN'] == ISBN, 'Image.URL.S'].iloc[0]
    print(ISBN)
    #print(df_imagelink.loc[df_imagelink['ISBN'] == ISBN, 'Image.URL.L'].iloc[0])
# Out:
# /Users/siliwang/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/siliwang/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/siliwang/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df1[df1['ISBN'] == '0002006588'].index[0]
# Out:
# 3

# %%
df_imagelink.loc[df_imagelink['ISBN'] == '0374157065', 'Image.URL.L'].iloc[0]
# Out:
# 'http://images.amazon.com/images/P/0374157065.01.LZZZZZZZ.jpg'

# %%
#del df1[0,'Image_L']

# %%
#del df1['Image_S']

# %%
#del df1['Image_M']

# %%
#df1

# %%
df1.to_csv('/Users/siliwang/Desktop/Data_with_ImageLink.csv')
